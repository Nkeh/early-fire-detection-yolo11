# %%
import ultralytics
ultralytics.checks()
# Out:
# Running cells with 'venv (3.12.2) (Python 3.12.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Ransom/Learning/computer_vision/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
